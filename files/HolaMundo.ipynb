# %% [markdown]
# ## Importación de librerías necesarias
#
# (En caso de no haberlo hecho, estas de deben instalar previamente)

# %%
from pyspark.sql import SparkSession
import os
from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import isnan, when, count, col, lit, trim, avg, ceil
from pyspark.sql.types import StringType
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Configuración del entorno
#
# Si este bloque de código genera error, se debe modificar el primer parámetro (JAVA_HOME) ajustandolo a la versión instalada.

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/opt/spark/spark-3.2.1-bin-hadoop3.2"

# %% [markdown]
# ## Descaraga de datasets desde AWS

# %%
# !wget https://s3.amazonaws.com/drivendata/data/7/public/4910797b-ee55-40a7-8668-10efd5c1b960.csv -O features.csv
# !wget https://s3.amazonaws.com/drivendata/data/7/public/0bf8bc6e-30d0-4c50-956a-603fc693d966.csv -O labels.csv
# Out:
# --2022-05-30 08:06:40--  https://s3.amazonaws.com/drivendata/data/7/public/4910797b-ee55-40a7-8668-10efd5c1b960.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.163.40
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.163.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20069199 (19M) [text/csv]
# Saving to: ‘features.csv’
#
# features.csv        100%[===================>]  19.14M  5.18MB/s    in 4.0s
#
# 2022-05-30 08:06:45 (4.78 MB/s) - ‘features.csv’ saved [20069199/20069199]
#
# --2022-05-30 08:06:45--  https://s3.amazonaws.com/drivendata/data/7/public/0bf8bc6e-30d0-4c50-956a-603fc693d966.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.172.232
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.172.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1148327 (1.1M) [text/csv]
# Saving to: ‘labels.csv’
#
# labels.csv          100%[===================>]   1.09M  2.90MB/s    in 0.4s
#
# 2022-05-30 08:06:46 (2.90 MB/s) - ‘labels.csv’ saved [1148327/1148327]

# %% [markdown]
# ## Definición del contexto de Spark utilizando todos los núcleos disponibles

# %%
sc = SparkSession.builder.master("local[*]").getOrCreate()
# Out:
# 22/05/30 08:07:39 WARN Utils: Your hostname, DESKTOP-L28I83P resolves to a loopback address: 127.0.1.1; using 172.22.69.52 instead (on interface eth0)
# 22/05/30 08:07:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark/spark-3.2.1-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/05/30 08:07:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Creación de dataframes a partir de la data descargada

# %%
feature = sc.read.csv("features.csv", inferSchema=True,header=True)
label = sc.read.csv("labels.csv", inferSchema=True,header=True)

# %% [markdown]
# ## Revisión de filas y columnas

# %%
print(feature.count())
print(label.count())
print(feature.columns)
print(label.columns)
# Out:
# 59400
# 59400
# ['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer', 'longitude', 'latitude', 'wpt_name', 'num_private', 'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward', 'population', 'public_meeting', 'recorded_by', 'scheme_management', 'scheme_name', 'permit', 'construction_year', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group']
# ['id', 'status_group']

# %% [markdown]
# ## Cruce de las dos tablas

# %%
data = feature.join(label, on=("id"))
print(data.count())
print(data.columns)
# Out:
# 59400
# ['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer', 'longitude', 'latitude', 'wpt_name', 'num_private', 'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward', 'population', 'public_meeting', 'recorded_by', 'scheme_management', 'scheme_name', 'permit', 'construction_year', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']

# %% [markdown]
# ## Impresión del schema de la tabla y 10 primeros registros

# %%
print(data.printSchema())
display(data.limit(10).toPandas())
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- amount_tsh: double (nullable = true)
#  |-- date_recorded: string (nullable = true)
#  |-- funder: string (nullable = true)
#  |-- gps_height: integer (nullable = true)
#  |-- installer: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- wpt_name: string (nullable = true)
#  |-- num_private: integer (nullable = true)
#  |-- basin: string (nullable = true)
#  |-- subvillage: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- region_code: integer (nullable = true)
#  |-- district_code: integer (nullable = true)
#  |-- lga: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- population: integer (nullable = true)
#  |-- public_meeting: boolean (nullable = true)
#  |-- recorded_by: string (nullable = true)
#  |-- scheme_management: string (nullable = true)
#  |-- scheme_name: string (nullable = true)
#  |-- permit: boolean (nullable = true)
#  |-- construction_year: integer (nullable = true)
#  |-- extraction_type: string (nullable = true)
#  |-- extraction_type_group: string (nullable = true)
#  |-- extraction_type_class: string (nullable = true)
#  |-- management: string (nullable = true)
#  |-- management_group: string (nullable = true)
#  |-- payment: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- water_quality: string (nullable = true)
#  |-- quality_group: string (nullable = true)
#  |-- quantity: string (nullable = true)
#  |-- quantity_group: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- source_type: string (nullable = true)
#  |-- source_class: string (nullable = true)
#  |-- waterpoint_type: string (nullable = true)
#  |-- waterpoint_type_group: string (nullable = true)
#  |-- status_group: string (nullable = true)
#
# None
#       id  amount_tsh date_recorded               funder  gps_height  \
# 0  69572      6000.0    2011-03-14                Roman        1390
# 1   8776         0.0    2013-03-06              Grumeti        1399
# 2  34310        25.0    2013-02-25         Lottery Club         686
# 3  67743         0.0    2013-01-28               Unicef         263
# 4  19728         0.0    2011-07-13          Action In A           0
# 5   9944        20.0    2011-03-13  Mkinga Distric Coun           0
# 6  19816         0.0    2012-10-01                 Dwsp           0
# 7  54551         0.0    2012-10-09                Rwssp           0
# 8  53934         0.0    2012-11-03             Wateraid           0
# 9  46144         0.0    2011-08-03          Isingiro Ho           0
#
#       installer  longitude   latitude              wpt_name  num_private  ...  \
# 0         Roman  34.938093  -9.856322                  none            0  ...
# 1       GRUMETI  34.698766  -2.147466              Zahanati            0  ...
# 2  World vision  37.460664  -3.821329           Kwa Mahundi            0  ...
# 3        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...
# 4       Artisan  31.130847  -1.825359               Shuleni            0  ...
# 5           DWE  39.172796  -4.765587                Tajiri            0  ...
# 6          DWSP  33.362410  -3.766365            Kwa Ngomho            0  ...
# 7           DWE  32.620617  -4.226198          Tushirikiane            0  ...
# 8     Water Aid  32.711100  -5.146712     Kwa Ramadhan Musa            0  ...
# 9       Artisan  30.626991  -1.257051               Kwapeto            0  ...
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
# 5         salty         salty        enough          enough
# 6          soft          good        enough          enough
# 7         milky         milky        enough          enough
# 8         salty         salty      seasonal        seasonal
# 9          soft          good        enough          enough
#
#                  source           source_type source_class  \
# 0                spring                spring  groundwater
# 1  rainwater harvesting  rainwater harvesting      surface
# 2                   dam                   dam      surface
# 3           machine dbh              borehole  groundwater
# 4  rainwater harvesting  rainwater harvesting      surface
# 5                 other                 other      unknown
# 6           machine dbh              borehole  groundwater
# 7          shallow well          shallow well  groundwater
# 8           machine dbh              borehole  groundwater
# 9          shallow well          shallow well  groundwater
#
#                waterpoint_type waterpoint_type_group    status_group
# 0           communal standpipe    communal standpipe      functional
# 1           communal standpipe    communal standpipe      functional
# 2  communal standpipe multiple    communal standpipe      functional
# 3  communal standpipe multiple    communal standpipe  non functional
# 4           communal standpipe    communal standpipe      functional
# 5  communal standpipe multiple    communal standpipe      functional
# 6                    hand pump             hand pump  non functional
# 7                    hand pump             hand pump  non functional
# 8                    hand pump             hand pump  non functional
# 9                    hand pump             hand pump      functional
#
# [10 rows x 41 columns]

# %% [markdown]
# ## Categorización de las variables `region_code` y `district_code` para su posterio utilización en modelos

# %%
data = data.withColumn('region_code', col('region_code').cast(StringType())).withColumn('district_code', col('district_code').cast(StringType()))

# %%
data
# Out:
# DataFrame[id: int, amount_tsh: double, date_recorded: string, funder: string, gps_height: int, installer: string, longitude: double, latitude: double, wpt_name: string, num_private: int, basin: string, subvillage: string, region: string, region_code: string, district_code: string, lga: string, ward: string, population: int, public_meeting: boolean, recorded_by: string, scheme_management: string, scheme_name: string, permit: boolean, construction_year: int, extraction_type: string, extraction_type_group: string, extraction_type_class: string, management: string, management_group: string, payment: string, payment_type: string, water_quality: string, quality_group: string, quantity: string, quantity_group: string, source: string, source_type: string, source_class: string, waterpoint_type: string, waterpoint_type_group: string, status_group: string]

# %% [markdown]
# ## Verificación del cambio de tipo

# %%
data.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- amount_tsh: double (nullable = true)
#  |-- date_recorded: string (nullable = true)
#  |-- funder: string (nullable = true)
#  |-- gps_height: integer (nullable = true)
#  |-- installer: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- wpt_name: string (nullable = true)
#  |-- num_private: integer (nullable = true)
#  |-- basin: string (nullable = true)
#  |-- subvillage: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- region_code: string (nullable = true)
#  |-- district_code: string (nullable = true)
#  |-- lga: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- population: integer (nullable = true)
#  |-- public_meeting: boolean (nullable = true)
#  |-- recorded_by: string (nullable = true)
#  |-- scheme_management: string (nullable = true)
#  |-- scheme_name: string (nullable = true)
#  |-- permit: boolean (nullable = true)
#  |-- construction_year: integer (nullable = true)
#  |-- extraction_type: string (nullable = true)
#  |-- extraction_type_group: string (nullable = true)
#  |-- extraction_type_class: string (nullable = true)
#  |-- management: string (nullable = true)
#  |-- management_group: string (nullable = true)
#  |-- payment: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- water_quality: string (nullable = true)
#  |-- quality_group: string (nullable = true)
#  |-- quantity: string (nullable = true)
#  |-- quantity_group: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- source_type: string (nullable = true)
#  |-- source_class: string (nullable = true)
#  |-- waterpoint_type: string (nullable = true)
#  |-- waterpoint_type_group: string (nullable = true)
#  |-- status_group: string (nullable = true)

# %% [markdown]
# ## Eliminación de registros duplicados

# %%
data = data.dropDuplicates(['id'])
data.count()
# Out:
# 59400

# %% [markdown]
# ## Identificación de columnas de tipo String

# %%
str_col = [item[0] for item in data.dtypes if item[1].startswith('string')]
str_col
# Out:
# ['date_recorded',
#  'funder',
#  'installer',
#  'wpt_name',
#  'basin',
#  'subvillage',
#  'region',
#  'region_code',
#  'district_code',
#  'lga',
#  'ward',
#  'recorded_by',
#  'scheme_management',
#  'scheme_name',
#  'extraction_type',
#  'extraction_type_group',
#  'extraction_type_class',
#  'management',
#  'management_group',
#  'payment',
#  'payment_type',
#  'water_quality',
#  'quality_group',
#  'quantity',
#  'quantity_group',
#  'source',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'waterpoint_type_group',
#  'status_group']

# %% [markdown]
# ## Eliminación de espacios en blanco

# %%
for cols in str_col:
  data = data.withColumn(cols, trim(data[cols]))

display(data.limit(20).toPandas())
# Out:
#      id  amount_tsh date_recorded                  funder  gps_height  \
# 0    26         0.0    2013-03-03                  Tassaf         949
# 1    27         0.0    2013-02-23  Government Of Tanzania         964
# 2    28         0.0    2011-07-29                    None           0
# 3    31      1000.0    2013-02-11                  Danida         576
# 4    34         0.0    2013-02-07                     Bgm           0
# 5    44        50.0    2011-03-27        District Council         521
# 6    65       500.0    2013-01-03                  Tassaf        1228
# 7    76         0.0    2012-10-30                 Grumeti        1394
# 8    78      3000.0    2013-02-02                  Danida         402
# 9    81         0.0    2012-11-04                  Hesawa           0
# 10  103      2000.0    2011-03-09                  Danida         955
# 11  108      1000.0    2013-08-02                  Danida         447
# 12  115        50.0    2011-03-12        District Council          10
# 13  126       200.0    2011-03-30  Government Of Tanzania        1345
# 14  133      1200.0    2011-03-26                   Villa        1314
# 15  137         0.0    2011-07-24               Community           0
# 16  148         0.0    2013-01-24        District Council         283
# 17  159         0.0    2013-03-15      Loliondo Secondary        2046
# 18  183         0.0    2013-01-17                    None        1635
# 19  192         0.0    2011-04-03                    None           0
#
#                     installer  longitude      latitude  \
# 0                      TASSAF  35.166289 -1.112649e+01
# 1                RUVUMA BASIN  35.142487 -1.068131e+01
# 2                        None  33.678669 -9.392807e+00
# 3                      DANIDA  37.236365 -1.100932e+01
# 4                         BGM  32.685457 -3.880662e+00
# 5         Handeni Trunk Main(  38.178901 -5.459401e+00
# 6                   Community  36.924137 -3.357655e+00
# 7                     GRUMETI  34.422111 -2.004985e+00
# 8                      DANIDA  37.692945 -1.117178e+01
# 9                         DWE   0.000000 -2.000000e-08
# 10                      DANID  35.138086 -7.829373e+00
# 11                     DANIDA  34.819688 -1.131223e+01
# 12                        DWE  38.971915 -5.454937e+00
# 13                        DWE  38.362334 -4.868908e+00
# 14                       Vill  34.844477 -8.557442e+00
# 15                  Community   0.000000 -2.000000e-08
# 16  District water department  39.124795 -9.902536e+00
# 17            Wasso companies  35.551120 -2.058582e+00
# 18                       None  35.043698 -4.643254e+00
# 19                       None  34.296745 -8.701206e+00
#
#                     wpt_name  num_private  ... water_quality quality_group  \
# 0           Kwa Mzee Nassibu            0  ...          soft          good
# 1            Kwa Mzee Hesawa            0  ...          soft          good
# 2                   Kilabuni            0  ...          soft          good
# 3      Ipanje Primary School            0  ...          soft          good
# 4                        Kwa            0  ...          soft          good
# 5       Kwa Ramadhani Kasidi            5  ...          soft          good
# 6                 Marko Akyo            0  ...          soft          good
# 7   Shule Ya Msingi Motukeri            0  ...          soft          good
# 8            Kwa Mzee Subati            0  ...         salty         salty
# 9                  Kwarugeni            0  ...         salty         salty
# 10                      none            0  ...          soft          good
# 11            Kwa Mzee Salim            0  ...          soft          good
# 12                  Manyanza            0  ...          soft          good
# 13           Kwa Mzee Zahabu            0  ...          soft          good
# 14                      none            0  ...          soft          good
# 15               B/Secondary            0  ...          soft          good
# 16                    Matuli            0  ...          soft          good
# 17                 Sekondari            0  ...          soft          good
# 18                    Msunga            0  ...          soft          good
# 19             Kwa Mwanyukwa            0  ...          soft          good
#
#         quantity quantity_group                source           source_type  \
# 0   insufficient   insufficient                spring                spring
# 1            dry            dry                spring                spring
# 2         enough         enough                spring                spring
# 3         enough         enough                 river            river/lake
# 4   insufficient   insufficient          shallow well          shallow well
# 5         enough         enough                 river            river/lake
# 6       seasonal       seasonal                 river            river/lake
# 7   insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 8   insufficient   insufficient           machine dbh              borehole
# 9   insufficient   insufficient          shallow well          shallow well
# 10        enough         enough                spring                spring
# 11        enough         enough                spring                spring
# 12  insufficient   insufficient          shallow well          shallow well
# 13        enough         enough                spring                spring
# 14        enough         enough                spring                spring
# 15  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 16       unknown        unknown                spring                spring
# 17  insufficient   insufficient           machine dbh              borehole
# 18  insufficient   insufficient           machine dbh              borehole
# 19      seasonal       seasonal                 river            river/lake
#
#    source_class              waterpoint_type waterpoint_type_group  \
# 0   groundwater           communal standpipe    communal standpipe
# 1   groundwater           communal standpipe    communal standpipe
# 2   groundwater           communal standpipe    communal standpipe
# 3       surface           communal standpipe    communal standpipe
# 4   groundwater                        other                 other
# 5       surface           communal standpipe    communal standpipe
# 6       surface           communal standpipe    communal standpipe
# 7       surface           communal standpipe    communal standpipe
# 8   groundwater                    hand pump             hand pump
# 9   groundwater                        other                 other
# 10  groundwater           communal standpipe    communal standpipe
# 11  groundwater           communal standpipe    communal standpipe
# 12  groundwater                    hand pump             hand pump
# 13  groundwater           communal standpipe    communal standpipe
# 14  groundwater           communal standpipe    communal standpipe
# 15      surface           communal standpipe    communal standpipe
# 16  groundwater  communal standpipe multiple    communal standpipe
# 17  groundwater           communal standpipe    communal standpipe
# 18  groundwater           communal standpipe    communal standpipe
# 19      surface           communal standpipe    communal standpipe
#
#                status_group
# 0                functional
# 1            non functional
# 2                functional
# 3            non functional
# 4            non functional
# 5                functional
# 6                functional
# 7                functional
# 8                functional
# 9            non functional
# 10               functional
# 11               functional
# 12               functional
# 13               functional
# 14           non functional
# 15               functional
# 16           non functional
# 17  functional needs repair
# 18  functional needs repair
# 19               functional
#
# [20 rows x 41 columns]
